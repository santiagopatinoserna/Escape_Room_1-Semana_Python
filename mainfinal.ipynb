# %%
import gdown
#https://drive.google.com/file/d/1J0v-U6DfjkcHY32RGG9ZqmKfKeSikIwh/view?usp=sharing

url = 'https://drive.google.com/uc?id=1J0v-U6DfjkcHY32RGG9ZqmKfKeSikIwh'  # Reemplaza 'file_id' con el ID real del archivo
output = 'funciones.py'  # Puedes especificar el nombre con el que quieres guardar el archivo
gdown.download(url, output, quiet=False)


import funciones as f

# define rooms and items

couch = {
    "name": "couch",
    "type": "furniture",
}

queenbed = {
    "name": "queen bed",
    "type": "furniture",
}

doublebed = {
    "name": "double bed",
    "type": "furniture",
}

dresser = {
    "name": "dresser",
    "type": "furniture",
}

diningtable = {
    "name": "dining table",
    "type": "furniture",
}

door_a = {
    "name": "door a",
    "type": "door",
}
door_b = {
    "name": "door b",
    "type": "door",
}

door_c = {
    "name": "door c",
    "type": "door",
}

door_d = {
    "name": "door d",
    "type": "door",
}

key_a = {
    "name": "key for door a",
    "type": "key",
    "target": door_a,
}

key_b = {
    "name": "key for door b",
    "type": "key",
    "target": door_b,
}

key_c = {
    "name": "key for door c",
    "type": "key",
    "target": door_c,
}

key_d = {
    "name": "key for door d",
    "type": "key",
    "target": door_d,
}

treasure = {
    "name": "treasure",
    "type": "treasure",
    "target": diningtable,
}

piano = {
    "name": "piano",
    "type": "furniture",
}

game_room = {
    "name": "game room",
    "type": "room",
}

bedroom1 = {
    "name": "bedroom1",
    "type": "room",
}

bedroom2 = {
    "name": "bedroom2",
    "type": "room",
}

livingroom = {
    "name": "livingroom",
    "type": "room",
}

outside = {
  "name": "outside",
  "type": "room",

}

all_rooms = [game_room, bedroom1, bedroom2, livingroom, outside]

all_doors = [door_a, door_b, door_c, door_d]


# define which items/rooms are related

object_relations = {
    "game room": [couch, piano, door_a, bedroom1],
    "piano": [key_a],
    "outside": [door_d],
    "door a": [game_room, bedroom1],
    "door b": [bedroom1, bedroom2,],
    "door c": [livingroom, bedroom1],
    "door d": [outside],
    "bedroom1": [queenbed, door_a, door_b, door_c],
    "queen bed": [key_b],
    "bedroom2": [doublebed, dresser, door_b],
    "double bed": [key_c],
    "dresser": [key_d],
    "livingroom":[diningtable, door_c, door_d],
    "dining table" : [treasure],
}

# define game state. Do not directly change this dict.
# Instead, when a new game starts, make a copy of this
# dict and use the copy to store gameplay state. This
# way you can replay the game multiple times.

INIT_GAME_STATE = {
    "current_room": game_room,
    "keys_collected": [],
    "target_room": outside,
    "treasure_collected":[],
    "escape_door": outside

}


f.start_game(INIT_GAME_STATE, object_relations)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1J0v-U6DfjkcHY32RGG9ZqmKfKeSikIwh
# From (redirected): https://drive.google.com/uc?id=1J0v-U6DfjkcHY32RGG9ZqmKfKeSikIwh&confirm=t&uuid=6446afea-99ce-41d8-8a85-4572ca6f633a
# To: /content/funciones.py
# 100%|██████████| 9.23k/9.23k [00:00<00:00, 4.17MB/s]
# Welcome to the game!
#
# Choose your difficulty level: 'easy' or 'hard':
# easy
# You selected Easy mode. You have to escape and maybe if you are good at researching you can find a reward!
#
# You wake up on a couch and find yourself in a strange house with no windows
#
# You don't remember why you are here and what had happened before. You have to find a way to go out
#
# You are now in game room
#
# What would you like to do? Type 'explore', 'examine' or 'push'?
# examine
#
# What would you like to examine?
# piano
# You examine piano. You find key for door a.
#
# You are now in game room
#
# What would you like to do? Type 'explore', 'examine' or 'push'?
# examine
# ...
